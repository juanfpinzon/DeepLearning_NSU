# %% [markdown]
# # HOME TASK 1

# %% [markdown]
# #### LOGISTIC REGRESSION TO CLASSIFY SENTIMENT FROM RUSSIAN TWEETS (BANK & TELECOM) USING TF-IDF VECTORIZER TO EXTRACT FEATURES

# %%
# Import of packages and libraries:
import pandas as pd
import xml.etree.cElementTree as et
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score
import re
###
#import gensim
#from keras.layers import Input
#from keras.layers.embeddings import Embedding
#from keras import optimizers
#from keras.layers import Dense, concatenate, Activation, Dropout
#from keras.models import Model
#from keras.layers.convolutional import Conv1D
#from keras.layers.pooling import GlobalMaxPooling1D
#
#from keras.preprocessing.text import Tokenizer
#from keras.preprocessing.sequence import pad_sequences
#from keras.utils import to_categorical
###

# %% [markdown]
# ## XML Parser:

# %%
def xml_parser(path):
    d = dict()
    root = et.parse(path)
    rows = root.findall('.//column')
    for row in rows:
        d.setdefault(list(row.attrib.values())[0],[]).append(row.text)
    df = pd.DataFrame.from_dict(d)
    return df

# %%
# Parse data:
data_train = pd.DataFrame()
data_test = pd.DataFrame()
path_train = ['tkk_train_2016.xml', 'bank_train_2016.xml']
path_test = ['tkk_test_etalon.xml', 'banks_test_etalon.xml']
for path in path_train:
    df = xml_parser(path)
    data_train = pd.concat([df, data_train], ignore_index=True)
for path in path_test:
    df = xml_parser(path)
    data_test = pd.concat([df, data_test], ignore_index=True)

# %%
data_train
# Out:
#       alfabank bankmoskvy beeline        date gazprom    id komstar megafon  \
# 0            0       NULL     NaN  1406224554    NULL     1     NaN     NaN
# 1         NULL       NULL     NaN  1406224691    NULL     2     NaN     NaN
# 2         NULL       NULL     NaN  1406224798    NULL     3     NaN     NaN
# 3         NULL       NULL     NaN  1406225412    NULL     4     NaN     NaN
# 4         NULL       NULL     NaN  1406226283    NULL     5     NaN     NaN
# 5         NULL          0     NaN  1406226450    NULL     6     NaN     NaN
# 6         NULL       NULL     NaN  1406226505    NULL     7     NaN     NaN
# 7         NULL       NULL     NaN  1406226960    NULL     9     NaN     NaN
# 8         NULL       NULL     NaN  1406226982    NULL    10     NaN     NaN
# 9         NULL       NULL     NaN  1406227218    NULL    11     NaN     NaN
# 10        NULL       NULL     NaN  1406227218    NULL    12     NaN     NaN
# 11           0       NULL     NaN  1406227462    NULL    13     NaN     NaN
# 12        NULL       NULL     NaN  1406227462    NULL    14     NaN     NaN
# 13        NULL       NULL     NaN  1406227585    NULL    15     NaN     NaN
# 14        NULL       NULL     NaN  1406228494    NULL    16     NaN     NaN
# 15        NULL       NULL     NaN  1406228524    NULL    17     NaN     NaN
# 16        NULL       NULL     NaN  1406228524       0    18     NaN     NaN
# 17        NULL       NULL     NaN  1406228544    NULL    19     NaN     NaN
# 18        NULL       NULL     NaN  1406228795    NULL    20     NaN     NaN
# 19        NULL       NULL     NaN  1406228880    NULL    21     NaN     NaN
# 20        NULL       NULL     NaN  1406232599    NULL    22     NaN     NaN
# 21        NULL       NULL     NaN  1406257672    NULL    23     NaN     NaN
# 22        NULL       NULL     NaN  1406257673    NULL    24     NaN     NaN
# 23        NULL       NULL     NaN  1406258046    NULL    25     NaN     NaN
# 24        NULL       NULL     NaN  1406258181    NULL    26     NaN     NaN
# 25        NULL       NULL     NaN  1406258263       0    27     NaN     NaN
# 26        NULL       NULL     NaN  1406258476      -1    28     NaN     NaN
# 27           0       NULL     NaN  1406258508    NULL    29     NaN     NaN
# 28        NULL       NULL     NaN  1406258549    NULL    30     NaN     NaN
# 29        NULL       NULL     NaN  1406258630    NULL    31     NaN     NaN
# ...        ...        ...     ...         ...     ...   ...     ...     ...
# 18005      NaN        NaN    NULL  1386954535     NaN  8816    NULL    NULL
# 18006      NaN        NaN    NULL  1386955405     NaN  8817    NULL    NULL
# 18007      NaN        NaN    NULL  1386961535     NaN  8818    NULL    NULL
# 18008      NaN        NaN    NULL  1387521073     NaN  8819    NULL    NULL
# 18009      NaN        NaN    NULL  1387773214     NaN  8820    NULL    NULL
# 18010      NaN        NaN    NULL  1387774309     NaN  8821    NULL    NULL
# 18011      NaN        NaN    NULL  1387774917     NaN  8822    NULL    NULL
# 18012      NaN        NaN    NULL  1387775031     NaN  8823    NULL    NULL
# 18013      NaN        NaN    NULL  1387776894     NaN  8824    NULL    NULL
# 18014      NaN        NaN    NULL  1387777635     NaN  8825    NULL    NULL
# 18015      NaN        NaN    NULL  1387778105     NaN  8826    NULL    NULL
# 18016      NaN        NaN    NULL  1387778471     NaN  8827    NULL    NULL
# 18017      NaN        NaN    NULL  1387780451     NaN  8828    NULL    NULL
# 18018      NaN        NaN    NULL  1387780451     NaN  8829    NULL    NULL
# 18019      NaN        NaN    NULL  1387780451     NaN  8830    NULL    NULL
# 18020      NaN        NaN    NULL  1387780451     NaN  8831    NULL    NULL
# 18021      NaN        NaN    NULL  1387781331     NaN  8832    NULL    NULL
# 18022      NaN        NaN    NULL  1387788423     NaN  8833    NULL    NULL
# 18023      NaN        NaN    NULL  1387791008     NaN  8834    NULL    NULL
# 18024      NaN        NaN    NULL  1387792816     NaN  8835    NULL    NULL
# 18025      NaN        NaN    NULL  1387793485     NaN  8836    NULL    NULL
# 18026      NaN        NaN    NULL  1387795050     NaN  8837    NULL    NULL
# 18027      NaN        NaN    NULL  1387796029     NaN  8838    NULL    NULL
# 18028      NaN        NaN    NULL  1387798984     NaN  8839    NULL    NULL
# 18029      NaN        NaN    NULL  1387800449     NaN  8840    NULL    NULL
# 18030      NaN        NaN    NULL  1387801265     NaN  8841    NULL    NULL
# 18031      NaN        NaN    NULL  1387805818     NaN  8842    NULL    NULL
# 18032      NaN        NaN    NULL  1387807952     NaN  8843    NULL    NULL
# 18033      NaN        NaN    NULL  1387808227     NaN  8844    NULL    NULL
# 18034      NaN        NaN    NULL  1387809204     NaN  8845    NULL    NULL
#
#        mts raiffeisen rostelecom  rshb sberbank skylink tele2  \
# 0      NaN       NULL        NaN  NULL     NULL     NaN   NaN
# 1      NaN       NULL        NaN  NULL     NULL     NaN   NaN
# 2      NaN          0        NaN  NULL     NULL     NaN   NaN
# 3      NaN       NULL        NaN  NULL        0     NaN   NaN
# 4      NaN       NULL        NaN  NULL        1     NaN   NaN
# 5      NaN       NULL        NaN  NULL     NULL     NaN   NaN
# 6      NaN       NULL        NaN  NULL     NULL     NaN   NaN
# 7      NaN       NULL        NaN  NULL        0     NaN   NaN
# 8      NaN       NULL        NaN     0     NULL     NaN   NaN
# 9      NaN       NULL        NaN  NULL     NULL     NaN   NaN
# 10     NaN         -1        NaN  NULL     NULL     NaN   NaN
# 11     NaN       NULL        NaN  NULL     NULL     NaN   NaN
# 12     NaN       NULL        NaN     0     NULL     NaN   NaN
# 13     NaN       NULL        NaN  NULL     NULL     NaN   NaN
# 14     NaN       NULL        NaN  NULL       -1     NaN   NaN
# 15     NaN       NULL        NaN  NULL        0     NaN   NaN
# 16     NaN       NULL        NaN  NULL     NULL     NaN   NaN
# 17     NaN       NULL        NaN  NULL        0     NaN   NaN
# 18     NaN       NULL        NaN  NULL       -1     NaN   NaN
# 19     NaN       NULL        NaN     0     NULL     NaN   NaN
# 20     NaN       NULL        NaN  NULL     NULL     NaN   NaN
# 21     NaN       NULL        NaN  NULL     NULL     NaN   NaN
# 22     NaN       NULL        NaN     0     NULL     NaN   NaN
# 23     NaN       NULL        NaN  NULL     NULL     NaN   NaN
# 24     NaN       NULL        NaN  NULL     NULL     NaN   NaN
# 25     NaN       NULL        NaN  NULL     NULL     NaN   NaN
# 26     NaN       NULL        NaN  NULL     NULL     NaN   NaN
# 27     NaN       NULL        NaN  NULL     NULL     NaN   NaN
# 28     NaN          0        NaN  NULL     NULL     NaN   NaN
# 29     NaN       NULL        NaN  NULL        0     NaN   NaN
# ...    ...        ...        ...   ...      ...     ...   ...
# 18005    1        NaN       NULL   NaN      NaN    NULL  NULL
# 18006   -1        NaN       NULL   NaN      NaN    NULL  NULL
# 18007   -1        NaN       NULL   NaN      NaN    NULL  NULL
# 18008    0        NaN       NULL   NaN      NaN    NULL  NULL
# 18009   -1        NaN       NULL   NaN      NaN    NULL  NULL
# 18010   -1        NaN       NULL   NaN      NaN    NULL  NULL
# 18011   -1        NaN       NULL   NaN      NaN    NULL  NULL
# 18012   -1        NaN       NULL   NaN      NaN    NULL  NULL
# 18013    1        NaN       NULL   NaN      NaN    NULL  NULL
# 18014    1        NaN       NULL   NaN      NaN    NULL  NULL
# 18015    1        NaN       NULL   NaN      NaN    NULL  NULL
# 18016    1        NaN       NULL   NaN      NaN    NULL  NULL
# 18017    1        NaN       NULL   NaN      NaN    NULL  NULL
# 18018    1        NaN       NULL   NaN      NaN    NULL  NULL
# 18019    1        NaN       NULL   NaN      NaN    NULL  NULL
# 18020    1        NaN       NULL   NaN      NaN    NULL  NULL
# 18021   -1        NaN       NULL   NaN      NaN    NULL  NULL
# 18022   -1        NaN       NULL   NaN      NaN    NULL  NULL
# 18023   -1        NaN       NULL   NaN      NaN    NULL  NULL
# 18024   -1        NaN       NULL   NaN      NaN    NULL  NULL
# 18025    1        NaN       NULL   NaN      NaN    NULL  NULL
# 18026   -1        NaN       NULL   NaN      NaN    NULL  NULL
# 18027    1        NaN       NULL   NaN      NaN    NULL  NULL
# 18028   -1        NaN       NULL   NaN      NaN    NULL  NULL
# 18029   -1        NaN       NULL   NaN      NaN    NULL  NULL
# 18030    1        NaN       NULL   NaN      NaN    NULL  NULL
# 18031   -1        NaN       NULL   NaN      NaN    NULL  NULL
# 18032   -1        NaN       NULL   NaN      NaN    NULL  NULL
# 18033   -1        NaN       NULL   NaN      NaN    NULL  NULL
# 18034   -1        NaN       NULL   NaN      NaN    NULL  NULL
#
#                                                     text              twitid  \
# 0      http://t.co/YEVHuvVGA1 Взять кредит тюмень аль...  492367586156630000
# 1      Мнение о кредитной карте втб 24 http://t.co/SB...  492368160923070000
# 2      «Райффайзенбанк»: Снижение ключевой ставки ЦБ ...  492368608346260000
# 3      Современное состояние кредитного поведения в р...  492371181946030000
# 4      @sawik_shuster @YevhenS Главное чтоб банки СБЕ...  492374836564750000
# 5      http://t.co/Qr6JbSVTxY Оформить краткосрочный ...  492375537080600000
# 6      Самый выгодный автокредит в втб 24 http://t.co...  492375766907510000
# 7      Кредит иногородним в москве сбербанк http://t....  492377674535680000
# 8      Кредитный калькулятор россельхозбанк чита http...  492377768232250000
# 9      http://t.co/h6r6GdBe4H Легко можно получить де...  492378757769220000
# 10     ДЕЛО -  На 1 млрд грн ушел в минус Райффайзен ...  492378758372800000
# 11     Део нексия в кредит в альфа банке http://t.co/...  492379779946260000
# 12     Россельхозбанк кредит стань фермером http://t....  492379780881590000
# 13     http://t.co/CuNsxVhAb0 Банк втб взять кредит 4...  492380298458710000
# 14     @ShtirliZ_ @Zhukova_olga @winzard @tereshenkov...  492384109483000000
# 15     Расчитать кредит сбер банк россии в москве htt...  492384237199580000
# 16     Кредит в газпром банке тула http://t.co/jqt7Nf...  492384237631570000
# 17     Кредитный калькулятор сбербанк россии http://t...  492384320926260000
# 18     @Umka_75 @Alfarius2012 @igor_sechin втб и сбер...  492385371649740000
# 19     http://t.co/Snn5WoPVcf Взять кредит строительс...  492385727242850000
# 20     Льготный период по кредитной карте втб 24 http...  492401325649690000
# 21     http://t.co/SqAiEPURl0 Казань банк втб 24 хочу...  492506491879190000
# 22     http://t.co/YtapffQchW Как взять кредит на раз...  492506495830200000
# 23     Оао банк втб северо запад в спб автокредит htt...  492508060754390000
# 24     http://t.co/6sKsurs9OH Оформить заявку на кред...  492508625018310000
# 25     http://t.co/v4cogwQQ1g Взять кредит в газпромб...  492508970482160000
# 26     Канада ввела санкции против Газпромбанка, ВЭБа...  492509863486840000
# 27     http://t.co/UYLSGYH8P6 Как взять денежный кред...  492509998220870000
# 28     Заявление на потребительский кредит в райффайз...  492510171139410000
# 29     http://t.co/c2r5fpTO6H Сбербанк кредит как пол...  492510508420180000
# ...                                                  ...                 ...
# 18005                  @ru_mts @mts_ukraine благодарю =)  411543266815787008
# 18006  RT @zamigehyrejy: мтс без 3г просто печале  не...  411546915432849408
# 18007  @ru_mts они уходят в ожидание на 5 минут и пот...  411572626868699136
# 18008  МТС - люди говорят! ФСБ - мы записываем! http:...  413919500195860480
# 18009  RT @css8574: У МТС проблемы со связью из-за за...  414977052975316992
# 18010  #МТС что со связью вновь? На островах вообще м...  414981647226773504
# 18011  @ru_mts, вы выделяете персонального менеджера,...  414984199154966528
# 18012  @ru_mts спасибо за ответ точнее за посыл в офи...  414984676579999744
# 18013  Zaletchikya МТС запустили в Новосибирской обла...  414992489553334272
# 18014  МТС запустила сеть LTE в Красноярском крае: Ко...  414995599277031424
# 18015             МТС запустила первую сеть LTE в Сибири  414997568616427520
# 18016  МТС запустила сеть LTE в Красноярском крае htt...  414999104184279040
# 18017  #news После Новосибирска МТС запустила сеть 4G...  415007409837314049
# 18018  После Новосибирска МТС запустила сеть 4G в Кра...  415007409078140928
# 18019  После Новосибирска МТС запустила сеть 4G в Кра...  415007408847454208
# 18020  После Новосибирска МТС запустила сеть 4G в Кра...  415007408570654720
# 18021  RT @winkk92: У МТС проблемы со связью из-за за...  415011099076206592
# 18022  RT @rozotinopad: У МТС проблемы со связью из-з...  415040844694319104
# 18023  RT @thespiderx3: У МТС проблемы со связью из-з...  415051688673021953
# 18024  RT @ssuhas78: У МТС проблемы со связью из-за з...  415059270217244672
# 18025                           @ru_mts ура!Спасибо Вам!  415062077443940352
# 18026  RT @alimov48: У МТС проблемы со связью из-за з...  415068642548920320
# 18027  RT @ru_mts: RT @mts_news: #LTE от #МТС шагает ...  415072750118531072
# 18028  Ура! После последних событий «минус 500 рублей...  415085142340673537
# 18029                   @iNikkiiiii подать в суд на МТС   415091285071249408
# 18030  Понедвечер /  / Сейчас буду делать уроки. Вот ...  415094710408323072
# 18031  Ну если-же это МТС,то скорость интернета будет...  415113805056593920
# 18032  RT @Olympialeigh: У МТС проблемы со связью из-...  415122755252940800
# 18033  RT @ManisaMerkez45: У МТС проблемы со связью и...  415123909592481793
# 18034  RT @MertKaraoban: У МТС проблемы со связью из-...  415128009017151488
#
#       uralsib   vtb
# 0        NULL  NULL
# 1        NULL     0
# 2        NULL  NULL
# 3        NULL  NULL
# 4        NULL     1
# 5        NULL  NULL
# 6        NULL     1
# 7        NULL  NULL
# 8        NULL  NULL
# 9        NULL     1
# 10       NULL     0
# 11       NULL  NULL
# 12       NULL  NULL
# 13       NULL     0
# 14       NULL  NULL
# 15       NULL  NULL
# 16       NULL  NULL
# 17       NULL  NULL
# 18       NULL    -1
# 19       NULL  NULL
# 20       NULL     0
# 21       NULL     0
# 22       NULL  NULL
# 23       NULL     0
# 24          0  NULL
# 25       NULL  NULL
# 26       NULL  NULL
# 27       NULL  NULL
# 28       NULL  NULL
# 29       NULL  NULL
# ...       ...   ...
# 18005     NaN   NaN
# 18006     NaN   NaN
# 18007     NaN   NaN
# 18008     NaN   NaN
# 18009     NaN   NaN
# 18010     NaN   NaN
# 18011     NaN   NaN
# 18012     NaN   NaN
# 18013     NaN   NaN
# 18014     NaN   NaN
# 18015     NaN   NaN
# 18016     NaN   NaN
# 18017     NaN   NaN
# 18018     NaN   NaN
# 18019     NaN   NaN
# 18020     NaN   NaN
# 18021     NaN   NaN
# 18022     NaN   NaN
# 18023     NaN   NaN
# 18024     NaN   NaN
# 18025     NaN   NaN
# 18026     NaN   NaN
# 18027     NaN   NaN
# 18028     NaN   NaN
# 18029     NaN   NaN
# 18030     NaN   NaN
# 18031     NaN   NaN
# 18032     NaN   NaN
# 18033     NaN   NaN
# 18034     NaN   NaN
#
# [18035 rows x 19 columns]

# %% [markdown]
# ## Data Preparation:

# %%
data_train.drop(['date', 'id', 'twitid'], axis=1, inplace = True, errors='ignore')
data_train.head()
# Out:
#   alfabank bankmoskvy beeline gazprom komstar megafon  mts raiffeisen  \
# 0        0       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 1     NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 2     NULL       NULL     NaN    NULL     NaN     NaN  NaN          0
# 3     NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 4     NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
#
#   rostelecom  rshb sberbank skylink tele2  \
# 0        NaN  NULL     NULL     NaN   NaN
# 1        NaN  NULL     NULL     NaN   NaN
# 2        NaN  NULL     NULL     NaN   NaN
# 3        NaN  NULL        0     NaN   NaN
# 4        NaN  NULL        1     NaN   NaN
#
#                                                 text uralsib   vtb
# 0  http://t.co/YEVHuvVGA1 Взять кредит тюмень аль...    NULL  NULL
# 1  Мнение о кредитной карте втб 24 http://t.co/SB...    NULL     0
# 2  «Райффайзенбанк»: Снижение ключевой ставки ЦБ ...    NULL  NULL
# 3  Современное состояние кредитного поведения в р...    NULL  NULL
# 4  @sawik_shuster @YevhenS Главное чтоб банки СБЕ...    NULL     1

# %%
data_train.fillna(0)
# Out:
#       alfabank bankmoskvy beeline gazprom komstar megafon mts raiffeisen  \
# 0            0       NULL       0    NULL       0       0   0       NULL
# 1         NULL       NULL       0    NULL       0       0   0       NULL
# 2         NULL       NULL       0    NULL       0       0   0          0
# 3         NULL       NULL       0    NULL       0       0   0       NULL
# 4         NULL       NULL       0    NULL       0       0   0       NULL
# 5         NULL          0       0    NULL       0       0   0       NULL
# 6         NULL       NULL       0    NULL       0       0   0       NULL
# 7         NULL       NULL       0    NULL       0       0   0       NULL
# 8         NULL       NULL       0    NULL       0       0   0       NULL
# 9         NULL       NULL       0    NULL       0       0   0       NULL
# 10        NULL       NULL       0    NULL       0       0   0         -1
# 11           0       NULL       0    NULL       0       0   0       NULL
# 12        NULL       NULL       0    NULL       0       0   0       NULL
# 13        NULL       NULL       0    NULL       0       0   0       NULL
# 14        NULL       NULL       0    NULL       0       0   0       NULL
# 15        NULL       NULL       0    NULL       0       0   0       NULL
# 16        NULL       NULL       0       0       0       0   0       NULL
# 17        NULL       NULL       0    NULL       0       0   0       NULL
# 18        NULL       NULL       0    NULL       0       0   0       NULL
# 19        NULL       NULL       0    NULL       0       0   0       NULL
# 20        NULL       NULL       0    NULL       0       0   0       NULL
# 21        NULL       NULL       0    NULL       0       0   0       NULL
# 22        NULL       NULL       0    NULL       0       0   0       NULL
# 23        NULL       NULL       0    NULL       0       0   0       NULL
# 24        NULL       NULL       0    NULL       0       0   0       NULL
# 25        NULL       NULL       0       0       0       0   0       NULL
# 26        NULL       NULL       0      -1       0       0   0       NULL
# 27           0       NULL       0    NULL       0       0   0       NULL
# 28        NULL       NULL       0    NULL       0       0   0          0
# 29        NULL       NULL       0    NULL       0       0   0       NULL
# ...        ...        ...     ...     ...     ...     ...  ..        ...
# 18005        0          0    NULL       0    NULL    NULL   1          0
# 18006        0          0    NULL       0    NULL    NULL  -1          0
# 18007        0          0    NULL       0    NULL    NULL  -1          0
# 18008        0          0    NULL       0    NULL    NULL   0          0
# 18009        0          0    NULL       0    NULL    NULL  -1          0
# 18010        0          0    NULL       0    NULL    NULL  -1          0
# 18011        0          0    NULL       0    NULL    NULL  -1          0
# 18012        0          0    NULL       0    NULL    NULL  -1          0
# 18013        0          0    NULL       0    NULL    NULL   1          0
# 18014        0          0    NULL       0    NULL    NULL   1          0
# 18015        0          0    NULL       0    NULL    NULL   1          0
# 18016        0          0    NULL       0    NULL    NULL   1          0
# 18017        0          0    NULL       0    NULL    NULL   1          0
# 18018        0          0    NULL       0    NULL    NULL   1          0
# 18019        0          0    NULL       0    NULL    NULL   1          0
# 18020        0          0    NULL       0    NULL    NULL   1          0
# 18021        0          0    NULL       0    NULL    NULL  -1          0
# 18022        0          0    NULL       0    NULL    NULL  -1          0
# 18023        0          0    NULL       0    NULL    NULL  -1          0
# 18024        0          0    NULL       0    NULL    NULL  -1          0
# 18025        0          0    NULL       0    NULL    NULL   1          0
# 18026        0          0    NULL       0    NULL    NULL  -1          0
# 18027        0          0    NULL       0    NULL    NULL   1          0
# 18028        0          0    NULL       0    NULL    NULL  -1          0
# 18029        0          0    NULL       0    NULL    NULL  -1          0
# 18030        0          0    NULL       0    NULL    NULL   1          0
# 18031        0          0    NULL       0    NULL    NULL  -1          0
# 18032        0          0    NULL       0    NULL    NULL  -1          0
# 18033        0          0    NULL       0    NULL    NULL  -1          0
# 18034        0          0    NULL       0    NULL    NULL  -1          0
#
#       rostelecom  rshb sberbank skylink tele2  \
# 0              0  NULL     NULL       0     0
# 1              0  NULL     NULL       0     0
# 2              0  NULL     NULL       0     0
# 3              0  NULL        0       0     0
# 4              0  NULL        1       0     0
# 5              0  NULL     NULL       0     0
# 6              0  NULL     NULL       0     0
# 7              0  NULL        0       0     0
# 8              0     0     NULL       0     0
# 9              0  NULL     NULL       0     0
# 10             0  NULL     NULL       0     0
# 11             0  NULL     NULL       0     0
# 12             0     0     NULL       0     0
# 13             0  NULL     NULL       0     0
# 14             0  NULL       -1       0     0
# 15             0  NULL        0       0     0
# 16             0  NULL     NULL       0     0
# 17             0  NULL        0       0     0
# 18             0  NULL       -1       0     0
# 19             0     0     NULL       0     0
# 20             0  NULL     NULL       0     0
# 21             0  NULL     NULL       0     0
# 22             0     0     NULL       0     0
# 23             0  NULL     NULL       0     0
# 24             0  NULL     NULL       0     0
# 25             0  NULL     NULL       0     0
# 26             0  NULL     NULL       0     0
# 27             0  NULL     NULL       0     0
# 28             0  NULL     NULL       0     0
# 29             0  NULL        0       0     0
# ...          ...   ...      ...     ...   ...
# 18005       NULL     0        0    NULL  NULL
# 18006       NULL     0        0    NULL  NULL
# 18007       NULL     0        0    NULL  NULL
# 18008       NULL     0        0    NULL  NULL
# 18009       NULL     0        0    NULL  NULL
# 18010       NULL     0        0    NULL  NULL
# 18011       NULL     0        0    NULL  NULL
# 18012       NULL     0        0    NULL  NULL
# 18013       NULL     0        0    NULL  NULL
# 18014       NULL     0        0    NULL  NULL
# 18015       NULL     0        0    NULL  NULL
# 18016       NULL     0        0    NULL  NULL
# 18017       NULL     0        0    NULL  NULL
# 18018       NULL     0        0    NULL  NULL
# 18019       NULL     0        0    NULL  NULL
# 18020       NULL     0        0    NULL  NULL
# 18021       NULL     0        0    NULL  NULL
# 18022       NULL     0        0    NULL  NULL
# 18023       NULL     0        0    NULL  NULL
# 18024       NULL     0        0    NULL  NULL
# 18025       NULL     0        0    NULL  NULL
# 18026       NULL     0        0    NULL  NULL
# 18027       NULL     0        0    NULL  NULL
# 18028       NULL     0        0    NULL  NULL
# 18029       NULL     0        0    NULL  NULL
# 18030       NULL     0        0    NULL  NULL
# 18031       NULL     0        0    NULL  NULL
# 18032       NULL     0        0    NULL  NULL
# 18033       NULL     0        0    NULL  NULL
# 18034       NULL     0        0    NULL  NULL
#
#                                                     text uralsib   vtb
# 0      http://t.co/YEVHuvVGA1 Взять кредит тюмень аль...    NULL  NULL
# 1      Мнение о кредитной карте втб 24 http://t.co/SB...    NULL     0
# 2      «Райффайзенбанк»: Снижение ключевой ставки ЦБ ...    NULL  NULL
# 3      Современное состояние кредитного поведения в р...    NULL  NULL
# 4      @sawik_shuster @YevhenS Главное чтоб банки СБЕ...    NULL     1
# 5      http://t.co/Qr6JbSVTxY Оформить краткосрочный ...    NULL  NULL
# 6      Самый выгодный автокредит в втб 24 http://t.co...    NULL     1
# 7      Кредит иногородним в москве сбербанк http://t....    NULL  NULL
# 8      Кредитный калькулятор россельхозбанк чита http...    NULL  NULL
# 9      http://t.co/h6r6GdBe4H Легко можно получить де...    NULL     1
# 10     ДЕЛО -  На 1 млрд грн ушел в минус Райффайзен ...    NULL     0
# 11     Део нексия в кредит в альфа банке http://t.co/...    NULL  NULL
# 12     Россельхозбанк кредит стань фермером http://t....    NULL  NULL
# 13     http://t.co/CuNsxVhAb0 Банк втб взять кредит 4...    NULL     0
# 14     @ShtirliZ_ @Zhukova_olga @winzard @tereshenkov...    NULL  NULL
# 15     Расчитать кредит сбер банк россии в москве htt...    NULL  NULL
# 16     Кредит в газпром банке тула http://t.co/jqt7Nf...    NULL  NULL
# 17     Кредитный калькулятор сбербанк россии http://t...    NULL  NULL
# 18     @Umka_75 @Alfarius2012 @igor_sechin втб и сбер...    NULL    -1
# 19     http://t.co/Snn5WoPVcf Взять кредит строительс...    NULL  NULL
# 20     Льготный период по кредитной карте втб 24 http...    NULL     0
# 21     http://t.co/SqAiEPURl0 Казань банк втб 24 хочу...    NULL     0
# 22     http://t.co/YtapffQchW Как взять кредит на раз...    NULL  NULL
# 23     Оао банк втб северо запад в спб автокредит htt...    NULL     0
# 24     http://t.co/6sKsurs9OH Оформить заявку на кред...       0  NULL
# 25     http://t.co/v4cogwQQ1g Взять кредит в газпромб...    NULL  NULL
# 26     Канада ввела санкции против Газпромбанка, ВЭБа...    NULL  NULL
# 27     http://t.co/UYLSGYH8P6 Как взять денежный кред...    NULL  NULL
# 28     Заявление на потребительский кредит в райффайз...    NULL  NULL
# 29     http://t.co/c2r5fpTO6H Сбербанк кредит как пол...    NULL  NULL
# ...                                                  ...     ...   ...
# 18005                  @ru_mts @mts_ukraine благодарю =)       0     0
# 18006  RT @zamigehyrejy: мтс без 3г просто печале  не...       0     0
# 18007  @ru_mts они уходят в ожидание на 5 минут и пот...       0     0
# 18008  МТС - люди говорят! ФСБ - мы записываем! http:...       0     0
# 18009  RT @css8574: У МТС проблемы со связью из-за за...       0     0
# 18010  #МТС что со связью вновь? На островах вообще м...       0     0
# 18011  @ru_mts, вы выделяете персонального менеджера,...       0     0
# 18012  @ru_mts спасибо за ответ точнее за посыл в офи...       0     0
# 18013  Zaletchikya МТС запустили в Новосибирской обла...       0     0
# 18014  МТС запустила сеть LTE в Красноярском крае: Ко...       0     0
# 18015             МТС запустила первую сеть LTE в Сибири       0     0
# 18016  МТС запустила сеть LTE в Красноярском крае htt...       0     0
# 18017  #news После Новосибирска МТС запустила сеть 4G...       0     0
# 18018  После Новосибирска МТС запустила сеть 4G в Кра...       0     0
# 18019  После Новосибирска МТС запустила сеть 4G в Кра...       0     0
# 18020  После Новосибирска МТС запустила сеть 4G в Кра...       0     0
# 18021  RT @winkk92: У МТС проблемы со связью из-за за...       0     0
# 18022  RT @rozotinopad: У МТС проблемы со связью из-з...       0     0
# 18023  RT @thespiderx3: У МТС проблемы со связью из-з...       0     0
# 18024  RT @ssuhas78: У МТС проблемы со связью из-за з...       0     0
# 18025                           @ru_mts ура!Спасибо Вам!       0     0
# 18026  RT @alimov48: У МТС проблемы со связью из-за з...       0     0
# 18027  RT @ru_mts: RT @mts_news: #LTE от #МТС шагает ...       0     0
# 18028  Ура! После последних событий «минус 500 рублей...       0     0
# 18029                   @iNikkiiiii подать в суд на МТС        0     0
# 18030  Понедвечер /  / Сейчас буду делать уроки. Вот ...       0     0
# 18031  Ну если-же это МТС,то скорость интернета будет...       0     0
# 18032  RT @Olympialeigh: У МТС проблемы со связью из-...       0     0
# 18033  RT @ManisaMerkez45: У МТС проблемы со связью и...       0     0
# 18034  RT @MertKaraoban: У МТС проблемы со связью из-...       0     0
#
# [18035 rows x 16 columns]

# %% [markdown]
# ## Get Labels:

# %%
def label(row):
    if (row == '1').any():
        label = 1
    elif (row == '0').any():
            label = 0
    else:
        label = -1
    return(label)

# %%
data_train['label'] = data_train.apply(label, axis=1)
data_train.label.value_counts()
# Out:
#  0    11832
# -1     4145
#  1     2058
# Name: label, dtype: int64

# %%
data_test['label'] = data_test.apply(label, axis=1)
data_test.label.value_counts()
# Out:
#  0    3251
# -1    1769
#  1     540
# Name: label, dtype: int64

# %% [markdown]
# ## Clean Text:

# %%
def clean_text(text):
    text = text.lower().replace("ё", "е")
    text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', 'URL', text)
    text = re.sub('@[^\s]+', 'USER', text)
    text = re.sub('[^a-zA-Zа-яА-Я1-9]+', ' ', text)
    text = re.sub(' +', ' ', text)
    return text.strip()

# %%
data_train['clean_text'] = data_train.text.apply(clean_text)
data_test['clean_text'] = data_test.text.apply(clean_text)

# %%
data_train
# Out:
#       alfabank bankmoskvy beeline gazprom komstar megafon  mts raiffeisen  \
# 0            0       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 1         NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 2         NULL       NULL     NaN    NULL     NaN     NaN  NaN          0
# 3         NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 4         NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 5         NULL          0     NaN    NULL     NaN     NaN  NaN       NULL
# 6         NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 7         NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 8         NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 9         NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 10        NULL       NULL     NaN    NULL     NaN     NaN  NaN         -1
# 11           0       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 12        NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 13        NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 14        NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 15        NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 16        NULL       NULL     NaN       0     NaN     NaN  NaN       NULL
# 17        NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 18        NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 19        NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 20        NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 21        NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 22        NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 23        NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 24        NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 25        NULL       NULL     NaN       0     NaN     NaN  NaN       NULL
# 26        NULL       NULL     NaN      -1     NaN     NaN  NaN       NULL
# 27           0       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# 28        NULL       NULL     NaN    NULL     NaN     NaN  NaN          0
# 29        NULL       NULL     NaN    NULL     NaN     NaN  NaN       NULL
# ...        ...        ...     ...     ...     ...     ...  ...        ...
# 18005      NaN        NaN    NULL     NaN    NULL    NULL    1        NaN
# 18006      NaN        NaN    NULL     NaN    NULL    NULL   -1        NaN
# 18007      NaN        NaN    NULL     NaN    NULL    NULL   -1        NaN
# 18008      NaN        NaN    NULL     NaN    NULL    NULL    0        NaN
# 18009      NaN        NaN    NULL     NaN    NULL    NULL   -1        NaN
# 18010      NaN        NaN    NULL     NaN    NULL    NULL   -1        NaN
# 18011      NaN        NaN    NULL     NaN    NULL    NULL   -1        NaN
# 18012      NaN        NaN    NULL     NaN    NULL    NULL   -1        NaN
# 18013      NaN        NaN    NULL     NaN    NULL    NULL    1        NaN
# 18014      NaN        NaN    NULL     NaN    NULL    NULL    1        NaN
# 18015      NaN        NaN    NULL     NaN    NULL    NULL    1        NaN
# 18016      NaN        NaN    NULL     NaN    NULL    NULL    1        NaN
# 18017      NaN        NaN    NULL     NaN    NULL    NULL    1        NaN
# 18018      NaN        NaN    NULL     NaN    NULL    NULL    1        NaN
# 18019      NaN        NaN    NULL     NaN    NULL    NULL    1        NaN
# 18020      NaN        NaN    NULL     NaN    NULL    NULL    1        NaN
# 18021      NaN        NaN    NULL     NaN    NULL    NULL   -1        NaN
# 18022      NaN        NaN    NULL     NaN    NULL    NULL   -1        NaN
# 18023      NaN        NaN    NULL     NaN    NULL    NULL   -1        NaN
# 18024      NaN        NaN    NULL     NaN    NULL    NULL   -1        NaN
# 18025      NaN        NaN    NULL     NaN    NULL    NULL    1        NaN
# 18026      NaN        NaN    NULL     NaN    NULL    NULL   -1        NaN
# 18027      NaN        NaN    NULL     NaN    NULL    NULL    1        NaN
# 18028      NaN        NaN    NULL     NaN    NULL    NULL   -1        NaN
# 18029      NaN        NaN    NULL     NaN    NULL    NULL   -1        NaN
# 18030      NaN        NaN    NULL     NaN    NULL    NULL    1        NaN
# 18031      NaN        NaN    NULL     NaN    NULL    NULL   -1        NaN
# 18032      NaN        NaN    NULL     NaN    NULL    NULL   -1        NaN
# 18033      NaN        NaN    NULL     NaN    NULL    NULL   -1        NaN
# 18034      NaN        NaN    NULL     NaN    NULL    NULL   -1        NaN
#
#       rostelecom  rshb sberbank skylink tele2  \
# 0            NaN  NULL     NULL     NaN   NaN
# 1            NaN  NULL     NULL     NaN   NaN
# 2            NaN  NULL     NULL     NaN   NaN
# 3            NaN  NULL        0     NaN   NaN
# 4            NaN  NULL        1     NaN   NaN
# 5            NaN  NULL     NULL     NaN   NaN
# 6            NaN  NULL     NULL     NaN   NaN
# 7            NaN  NULL        0     NaN   NaN
# 8            NaN     0     NULL     NaN   NaN
# 9            NaN  NULL     NULL     NaN   NaN
# 10           NaN  NULL     NULL     NaN   NaN
# 11           NaN  NULL     NULL     NaN   NaN
# 12           NaN     0     NULL     NaN   NaN
# 13           NaN  NULL     NULL     NaN   NaN
# 14           NaN  NULL       -1     NaN   NaN
# 15           NaN  NULL        0     NaN   NaN
# 16           NaN  NULL     NULL     NaN   NaN
# 17           NaN  NULL        0     NaN   NaN
# 18           NaN  NULL       -1     NaN   NaN
# 19           NaN     0     NULL     NaN   NaN
# 20           NaN  NULL     NULL     NaN   NaN
# 21           NaN  NULL     NULL     NaN   NaN
# 22           NaN     0     NULL     NaN   NaN
# 23           NaN  NULL     NULL     NaN   NaN
# 24           NaN  NULL     NULL     NaN   NaN
# 25           NaN  NULL     NULL     NaN   NaN
# 26           NaN  NULL     NULL     NaN   NaN
# 27           NaN  NULL     NULL     NaN   NaN
# 28           NaN  NULL     NULL     NaN   NaN
# 29           NaN  NULL        0     NaN   NaN
# ...          ...   ...      ...     ...   ...
# 18005       NULL   NaN      NaN    NULL  NULL
# 18006       NULL   NaN      NaN    NULL  NULL
# 18007       NULL   NaN      NaN    NULL  NULL
# 18008       NULL   NaN      NaN    NULL  NULL
# 18009       NULL   NaN      NaN    NULL  NULL
# 18010       NULL   NaN      NaN    NULL  NULL
# 18011       NULL   NaN      NaN    NULL  NULL
# 18012       NULL   NaN      NaN    NULL  NULL
# 18013       NULL   NaN      NaN    NULL  NULL
# 18014       NULL   NaN      NaN    NULL  NULL
# 18015       NULL   NaN      NaN    NULL  NULL
# 18016       NULL   NaN      NaN    NULL  NULL
# 18017       NULL   NaN      NaN    NULL  NULL
# 18018       NULL   NaN      NaN    NULL  NULL
# 18019       NULL   NaN      NaN    NULL  NULL
# 18020       NULL   NaN      NaN    NULL  NULL
# 18021       NULL   NaN      NaN    NULL  NULL
# 18022       NULL   NaN      NaN    NULL  NULL
# 18023       NULL   NaN      NaN    NULL  NULL
# 18024       NULL   NaN      NaN    NULL  NULL
# 18025       NULL   NaN      NaN    NULL  NULL
# 18026       NULL   NaN      NaN    NULL  NULL
# 18027       NULL   NaN      NaN    NULL  NULL
# 18028       NULL   NaN      NaN    NULL  NULL
# 18029       NULL   NaN      NaN    NULL  NULL
# 18030       NULL   NaN      NaN    NULL  NULL
# 18031       NULL   NaN      NaN    NULL  NULL
# 18032       NULL   NaN      NaN    NULL  NULL
# 18033       NULL   NaN      NaN    NULL  NULL
# 18034       NULL   NaN      NaN    NULL  NULL
#
#                                                     text uralsib   vtb  label  \
# 0      http://t.co/YEVHuvVGA1 Взять кредит тюмень аль...    NULL  NULL      0
# 1      Мнение о кредитной карте втб 24 http://t.co/SB...    NULL     0      0
# 2      «Райффайзенбанк»: Снижение ключевой ставки ЦБ ...    NULL  NULL      0
# 3      Современное состояние кредитного поведения в р...    NULL  NULL      0
# 4      @sawik_shuster @YevhenS Главное чтоб банки СБЕ...    NULL     1      1
# 5      http://t.co/Qr6JbSVTxY Оформить краткосрочный ...    NULL  NULL      0
# 6      Самый выгодный автокредит в втб 24 http://t.co...    NULL     1      1
# 7      Кредит иногородним в москве сбербанк http://t....    NULL  NULL      0
# 8      Кредитный калькулятор россельхозбанк чита http...    NULL  NULL      0
# 9      http://t.co/h6r6GdBe4H Легко можно получить де...    NULL     1      1
# 10     ДЕЛО -  На 1 млрд грн ушел в минус Райффайзен ...    NULL     0      0
# 11     Део нексия в кредит в альфа банке http://t.co/...    NULL  NULL      0
# 12     Россельхозбанк кредит стань фермером http://t....    NULL  NULL      0
# 13     http://t.co/CuNsxVhAb0 Банк втб взять кредит 4...    NULL     0      0
# 14     @ShtirliZ_ @Zhukova_olga @winzard @tereshenkov...    NULL  NULL     -1
# 15     Расчитать кредит сбер банк россии в москве htt...    NULL  NULL      0
# 16     Кредит в газпром банке тула http://t.co/jqt7Nf...    NULL  NULL      0
# 17     Кредитный калькулятор сбербанк россии http://t...    NULL  NULL      0
# 18     @Umka_75 @Alfarius2012 @igor_sechin втб и сбер...    NULL    -1     -1
# 19     http://t.co/Snn5WoPVcf Взять кредит строительс...    NULL  NULL      0
# 20     Льготный период по кредитной карте втб 24 http...    NULL     0      0
# 21     http://t.co/SqAiEPURl0 Казань банк втб 24 хочу...    NULL     0      0
# 22     http://t.co/YtapffQchW Как взять кредит на раз...    NULL  NULL      0
# 23     Оао банк втб северо запад в спб автокредит htt...    NULL     0      0
# 24     http://t.co/6sKsurs9OH Оформить заявку на кред...       0  NULL      0
# 25     http://t.co/v4cogwQQ1g Взять кредит в газпромб...    NULL  NULL      0
# 26     Канада ввела санкции против Газпромбанка, ВЭБа...    NULL  NULL     -1
# 27     http://t.co/UYLSGYH8P6 Как взять денежный кред...    NULL  NULL      0
# 28     Заявление на потребительский кредит в райффайз...    NULL  NULL      0
# 29     http://t.co/c2r5fpTO6H Сбербанк кредит как пол...    NULL  NULL      0
# ...                                                  ...     ...   ...    ...
# 18005                  @ru_mts @mts_ukraine благодарю =)     NaN   NaN      1
# 18006  RT @zamigehyrejy: мтс без 3г просто печале  не...     NaN   NaN     -1
# 18007  @ru_mts они уходят в ожидание на 5 минут и пот...     NaN   NaN     -1
# 18008  МТС - люди говорят! ФСБ - мы записываем! http:...     NaN   NaN      0
# 18009  RT @css8574: У МТС проблемы со связью из-за за...     NaN   NaN     -1
# 18010  #МТС что со связью вновь? На островах вообще м...     NaN   NaN     -1
# 18011  @ru_mts, вы выделяете персонального менеджера,...     NaN   NaN     -1
# 18012  @ru_mts спасибо за ответ точнее за посыл в офи...     NaN   NaN     -1
# 18013  Zaletchikya МТС запустили в Новосибирской обла...     NaN   NaN      1
# 18014  МТС запустила сеть LTE в Красноярском крае: Ко...     NaN   NaN      1
# 18015             МТС запустила первую сеть LTE в Сибири     NaN   NaN      1
# 18016  МТС запустила сеть LTE в Красноярском крае htt...     NaN   NaN      1
# 18017  #news После Новосибирска МТС запустила сеть 4G...     NaN   NaN      1
# 18018  После Новосибирска МТС запустила сеть 4G в Кра...     NaN   NaN      1
# 18019  После Новосибирска МТС запустила сеть 4G в Кра...     NaN   NaN      1
# 18020  После Новосибирска МТС запустила сеть 4G в Кра...     NaN   NaN      1
# 18021  RT @winkk92: У МТС проблемы со связью из-за за...     NaN   NaN     -1
# 18022  RT @rozotinopad: У МТС проблемы со связью из-з...     NaN   NaN     -1
# 18023  RT @thespiderx3: У МТС проблемы со связью из-з...     NaN   NaN     -1
# 18024  RT @ssuhas78: У МТС проблемы со связью из-за з...     NaN   NaN     -1
# 18025                           @ru_mts ура!Спасибо Вам!     NaN   NaN      1
# 18026  RT @alimov48: У МТС проблемы со связью из-за з...     NaN   NaN     -1
# 18027  RT @ru_mts: RT @mts_news: #LTE от #МТС шагает ...     NaN   NaN      1
# 18028  Ура! После последних событий «минус 500 рублей...     NaN   NaN     -1
# 18029                   @iNikkiiiii подать в суд на МТС      NaN   NaN     -1
# 18030  Понедвечер /  / Сейчас буду делать уроки. Вот ...     NaN   NaN      1
# 18031  Ну если-же это МТС,то скорость интернета будет...     NaN   NaN     -1
# 18032  RT @Olympialeigh: У МТС проблемы со связью из-...     NaN   NaN     -1
# 18033  RT @ManisaMerkez45: У МТС проблемы со связью и...     NaN   NaN     -1
# 18034  RT @MertKaraoban: У МТС проблемы со связью из-...     NaN   NaN     -1
#
#                                               clean_text
# 0                     URL взять кредит тюмень альфа банк
# 1                    мнение о кредитной карте втб 24 URL
# 2      райффайзенбанк снижение ключевой ставки цб на ...
# 3      современное состояние кредитного поведения в р...
# 4                USER USER главное чтоб банки сбер и втб
# 5      URL оформить краткосрочный кредит оао банк москвы
# 6                 самый выгодный автокредит в втб 24 URL
# 7               кредит иногородним в москве сбербанк URL
# 8          кредитный калькулятор россельхозбанк чита URL
# 9      URL легко можно получить денежный кредит ы втб...
# 10     дело на 1 млрд грн ушел в минус райффайзен бан...
# 11                 део нексия в кредит в альфа банке URL
# 12              россельхозбанк кредит стань фермером URL
# 13                           URL банк втб взять кредит 4
# 14     USER USER USER USER обязательно про сбербанк н...
# 15        расчитать кредит сбер банк россии в москве URL
# 16                       кредит в газпром банке тула URL
# 17             кредитный калькулятор сбербанк россии URL
# 18     USER USER USER втб и сбер точно вопрос блокиро...
# 19     URL взять кредит строительство магазина россел...
# 20         льготный период по кредитной карте втб 24 URL
# 21     URL казань банк втб 24 хочу взять кредит мне 2...
# 22     URL как взять кредит на развитие хозяйства рос...
# 23        оао банк втб северо запад в спб автокредит URL
# 24          URL оформить заявку на кредит в банк уралсиб
# 25         URL взять кредит в газпромбанке какие условия
# 26     канада ввела санкции против газпромбанка вэба ...
# 27           URL как взять денежный кредит в альфа банке
# 28     заявление на потребительский кредит в райффайз...
# 29                      URL сбербанк кредит как получить
# ...                                                  ...
# 18005                                USER USER благодарю
# 18006  rt USER мтс без 3г просто печале неговоря уже ...
# 18007  USER они уходят в ожидание на 5 минут и потом ...
# 18008             мтс люди говорят фсб мы записываем URL
# 18009  rt USER у мтс проблемы со связью из за замены ...
# 18010  мтс что со связью вновь на островах вообще мес...
# 18011  USER вы выделяете персонального менеджера но н...
# 18012  USER спасибо за ответ точнее за посыл в офис н...
# 18013  zaletchikya мтс запустили в новосибирской обла...
# 18014  мтс запустила сеть lte в красноярском крае ком...
# 18015             мтс запустила первую сеть lte в сибири
# 18016     мтс запустила сеть lte в красноярском крае URL
# 18017  news после новосибирска мтс запустила сеть 4g ...
# 18018  после новосибирска мтс запустила сеть 4g в кра...
# 18019  после новосибирска мтс запустила сеть 4g в кра...
# 18020  после новосибирска мтс запустила сеть 4g в кра...
# 18021  rt USER у мтс проблемы со связью из за замены ...
# 18022  rt USER у мтс проблемы со связью из за замены ...
# 18023  rt USER у мтс проблемы со связью из за замены ...
# 18024  rt USER у мтс проблемы со связью из за замены ...
# 18025                               USER ура спасибо вам
# 18026  rt USER у мтс проблемы со связью из за замены ...
# 18027  rt USER rt USER lte от мтс шагает по стране се...
# 18028  ура после последних событий минус 5 рублей с U...
# 18029                           USER подать в суд на мтс
# 18030  понедвечер сейчас буду делать уроки вот такая ...
# 18031  ну если же это мтс то скорость интернета будет...
# 18032  rt USER у мтс проблемы со связью из за замены ...
# 18033  rt USER у мтс проблемы со связью из за замены ...
# 18034  rt USER у мтс проблемы со связью из за замены ...
#
# [18035 rows x 18 columns]

# %% [markdown]
# ## TF-IDF Vectorizer:

# %%
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(data_train.text)
X_train.shape
# Out:
# /Users/juan/anaconda3/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# (18035, 35957)

# %%
X_test = vectorizer.transform(data_test.text)
X_test.shape
# Out:
# /Users/juan/anaconda3/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# (5560, 35957)

# %% [markdown]
# ## Logistic Regression Model:

# %%
model = LogisticRegression(multi_class='ovr')

# %%
model.fit(X_train, data_train.label)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# ### Results:

# %%
score = model.score(X_test, data_test.label)
print('Model Accuracy:', (score*100), '%')
# Out:
# Model Accuracy: 70.70143884892086 %
